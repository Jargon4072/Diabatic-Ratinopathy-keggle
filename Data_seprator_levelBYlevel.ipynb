# %%
import pandas as pd
import csv

# %%
train_df=pd.read_csv('data/trainLabels.csv')
train_df.head();

print(train_df)
# Out:
#                   image  level
# 0          10_left.jpeg      0
# 1         10_right.jpeg      0
# 2          13_left.jpeg      0
# 3         13_right.jpeg      0
# 4          15_left.jpeg      1
# 5         15_right.jpeg      2
# 6          16_left.jpeg      4
# 7         16_right.jpeg      4
# 8          17_left.jpeg      0
# 9         17_right.jpeg      1
# 10         19_left.jpeg      0
# 11        19_right.jpeg      0
# 12         20_left.jpeg      0
# 13        20_right.jpeg      0
# 14         21_left.jpeg      0
# 15        21_right.jpeg      0
# 16         22_left.jpeg      0
# 17        22_right.jpeg      0
# 18         23_left.jpeg      0
# 19        23_right.jpeg      0
# 20         25_left.jpeg      0
# 21        25_right.jpeg      0
# 22         30_left.jpeg      1
# 23        30_right.jpeg      2
# 24         31_left.jpeg      0
# 25        31_right.jpeg      0
# 26         33_left.jpeg      0
# 27        33_right.jpeg      0
# 28         36_left.jpeg      1
# ...

# %%
#get all level zero image names in train_0 dataframe.
train_0=train_df[(train_df['level']==0)]
print(train_0['image'])
# Out:
# 0            10_left.jpeg
# 1           10_right.jpeg
# 2            13_left.jpeg
# 3           13_right.jpeg
# 8            17_left.jpeg
# 10           19_left.jpeg
# 11          19_right.jpeg
# 12           20_left.jpeg
# 13          20_right.jpeg
# 14           21_left.jpeg
# 15          21_right.jpeg
# 16           22_left.jpeg
# 17          22_right.jpeg
# 18           23_left.jpeg
# 19          23_right.jpeg
# 20           25_left.jpeg
# 21          25_right.jpeg
# 24           31_left.jpeg
# 25          31_right.jpeg
# 26           33_left.jpeg
# 27          33_right.jpeg
# 29          36_right.jpeg
# 31          40_right.jpeg
# 32           41_left.jpeg
# 33          41_right.jpeg
# 34           42_left.jpeg
# 35          42_right.jpeg
# 36           46_left.jpeg
# 37          46_right.jpeg
# 38           47_left.jpeg
#                ...
# 35089    44298_right.jpeg
# 35090     44306_left.jpeg
# 35091    44306_right.jpeg
# 35092     44308_left.jpeg
# ...

# %%
import shutil
import os
import sys
import os.path
train_0['image'].to_csv("train1.csv",index=False)
src ='/media/krishna_warrior/B8006E18006DDDBE/Kaggel_Data_Set/train'
dst='/home/krishna_warrior/Desktop/dr_aison_test/level0'

CSVFile = '/home/krishna_warrior/Desktop/dr_aison_test/train1.csv'
for images in train_0['image']:
    srcpath = os.path.join(src, images)
    dstpath = os.path.join(dst, images)
    shutil.copyfile(srcpath, dstpath)

# %%
train_1=train_df[(train_df['level']==1)]
print(train_1['image'])
# Out:
# 4            15_left.jpeg
# 9           17_right.jpeg
# 22           30_left.jpeg
# 28           36_left.jpeg
# 102         114_left.jpeg
# 103        114_right.jpeg
# 150         178_left.jpeg
# 151        178_right.jpeg
# 173        204_right.jpeg
# 180         214_left.jpeg
# 196         227_left.jpeg
# 200         231_left.jpeg
# 211        240_right.jpeg
# 257        301_right.jpeg
# 272         320_left.jpeg
# 296         348_left.jpeg
# 297        348_right.jpeg
# 317        374_right.jpeg
# 337        393_right.jpeg
# 360         417_left.jpeg
# 361        417_right.jpeg
# 366         421_left.jpeg
# 378         435_left.jpeg
# 379        435_right.jpeg
# 421        487_right.jpeg
# 450         525_left.jpeg
# 451        525_right.jpeg
# 452         527_left.jpeg
# 472         560_left.jpeg
# 476         566_left.jpeg
#                ...
# 34619    43753_right.jpeg
# 34683    43822_right.jpeg
# 34684     43826_left.jpeg
# 34744     43902_left.jpeg
# ...

# %%
src ='/media/krishna_warrior/B8006E18006DDDBE/Kaggel_Data_Set/train'
dst='/home/krishna_warrior/Desktop/dr_aison_test/level1'

CSVFile = '/home/krishna_warrior/Desktop/dr_aison_test/train1.csv'
for images in train_1['image']:
    srcpath = os.path.join(src, images)
    dstpath = os.path.join(dst, images)
    shutil.copyfile(srcpath, dstpath)

# %%
train_2=train_df[(train_df['level']==2)]
print(train_2['image'])
# Out:
# 5           15_right.jpeg
# 23          30_right.jpeg
# 30           40_left.jpeg
# 42           51_left.jpeg
# 46           54_left.jpeg
# 47          54_right.jpeg
# 78           78_left.jpeg
# 79          78_right.jpeg
# 80           79_left.jpeg
# 81          79_right.jpeg
# 84           82_left.jpeg
# 85          82_right.jpeg
# 114         129_left.jpeg
# 115        129_right.jpeg
# 123        155_right.jpeg
# 144         172_left.jpeg
# 145        172_right.jpeg
# 154         184_left.jpeg
# 155        184_right.jpeg
# 160         192_left.jpeg
# 161        192_right.jpeg
# 164         195_left.jpeg
# 165        195_right.jpeg
# 188         219_left.jpeg
# 199        229_right.jpeg
# 208         239_left.jpeg
# 209        239_right.jpeg
# 224         257_left.jpeg
# 225        257_right.jpeg
# 234         264_left.jpeg
#                ...
# 34795    43975_right.jpeg
# 34804     43985_left.jpeg
# 34805    43985_right.jpeg
# 34819    43998_right.jpeg
# ...

# %%
src ='/media/krishna_warrior/B8006E18006DDDBE/Kaggel_Data_Set/train'
dst='/home/krishna_warrior/Desktop/dr_aison_test/level2'

for images in train_2['image']:
    srcpath = os.path.join(src, images)
    dstpath = os.path.join(dst, images)
    shutil.copyfile(srcpath, dstpath)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-a68ea631da4c> in <module>()
#       5     srcpath = os.path.join(src, images)
#       6     dstpath = os.path.join(dst, images)
# ----> 7     shutil.copyfile(srcpath, dstpath)
#
# /usr/lib/python3.6/shutil.py in copyfile(src, dst, follow_symlinks)
#     120         with open(src, 'rb') as fsrc:
#     121             with open(dst, 'wb') as fdst:
# --> 122                 copyfileobj(fsrc, fdst)
#     123     return dst
#     124
#
# /usr/lib/python3.6/shutil.py in copyfileobj(fsrc, fdst, length)
#      77     """copy data from file-like object fsrc to file-like object fdst"""
#      78     while 1:
# ---> 79         buf = fsrc.read(length)
#      80         if not buf:
#      81             break
#
# KeyboardInterrupt:
